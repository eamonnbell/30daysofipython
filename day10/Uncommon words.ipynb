# %% [markdown]
# # Day 10: Uncommon words in top 100 songs
#
# Using `spaCy` and Beautiful Soup to look at uncommon words in chart songs. `spaCy` has a database of prior probabilities in its English vocabulary, so we just tokenize each song, look up the prior independent probability of each token appearing in the vocab and sort the tokens by their probability. But there are major problems with the tokenization: it struggles with abbreviations (to investigate); also, some words are just not in the vocab and they return a probablity of 0.0 and they get dumped even if they might be informative. The results show the song title, artist, and the words that are in the song that occur least frequently in the English language (as modeled by the `spaCy` vocab).

# %%
from spacy.en import English
import requests
import bs4

# %%
nlp = English()

# %%
r = requests.get('http://lyrics.wikia.com/LyricWiki:Top_100')

# %%
soup = bs4.BeautifulSoup(r.content)

# %%
ordered_list = soup.find('ol')

# %%
links = []

for item in ordered_list.find_all('li'):
    link = item.a['href']
    if 'edit' not in link:
        links.append(link)

# %%
BASE = 'http://lyrics.wikia.com'

songs = []
master = []

for index, link in enumerate(links):
    r = requests.get(BASE + link)
    
    soup = bs4.BeautifulSoup(r.content)
    
    # Lyrics in a <div>
    
    lyrics = soup.find('div', attrs={'class':'lyricbox'})
    lines = [t for t in lyrics.contents if type(t) == bs4.element.NavigableString]
    title = soup.title.text.split('Lyrics')[0].strip()
    song = "\n".join(lines)
    record = {
        'id' : index,
        'title' : title
    }
    master.append(record)
    songs.append(song)

# %%
parsed = [nlp(song) for song in songs]

# %%
for index, tokens in enumerate(parsed):
    corpus_probs = []
    for tok in tokens:
        corpus_probs.append((tok.string, nlp.vocab[tok.string].prob))
    corpus_probs = list(set(corpus_probs))
    
    top_ten = sorted(corpus_probs, key=lambda x: x[1])[:10]
    
    title = (x for x in master if x['id'] == index).next()['title']
    
    print title
    
    print ' '.join([word[0] for word in top_ten])
    print '\n'
# Out:
# Fetty Wap:My Way
# ai morn shit wo seventeen ca Bitch baddest hoes bitch
#
#
# Omi:Cheerleader
# wand cheerleader tempting yeah cheating affection motivation queen selection mention
#
#
# The Weeknd:Can't Feel My Face
# ca numb yeah woo oh girl Do love young come
#
#
# Rachel Platten:Fight Song
# bones waves ocean Everybody sleep tonight motion song brain boat
#
#
# Silento:Watch Me (Whip / Nae Nae)
# duff superman ooh bop Okay whip legs leg ! me
#
#
# 5 Seconds Of Summer:She's Kinda Hot
# bitchin meds slob cuatro na Uno tres insane dos esteem
#
#
# The Weeknd:The Hills
# gon ca decaf promo babe relapse info rehab tempo yeah
#
#
# Selena Gomez:Good For You
# n't mmm wo carats Midas carat huh Uh uh jealous
#
#
# Andy Grammer:Honey, I'm Good.
# ooo adieu grail ass ya oh honey hell lie everywhere
#
#
# Major Lazer & DJ Snake:Lean On
# Innocent kiss sidewalk blows recall warm remember gun road young
#
#
# Fetty Wap:679
# Dicey gon ai aye ay bimbos Diddy Loon Blowing rewind
#
#
# Walk The Moon:Shut Up And Dance
# kryptonite ooh sneaks Juliet destiny Oh dance dream chemical arm
#
#
# Luke Bryan:Kick The Dust Up
# floorboard Tractors Clear Cadillac diesel Baby drinks ear nobody song
#
#
# Jack Ü:Where Are Ü Now
# sayin playin moping ca ya m Could Lord anywhere y
#
#
# Taylor Swift:Bad Blood
# n't 'em wo Mmm rusted hey ghosts shining Band breathe
#
#
# Fifth Harmony:Worth It
# playin ooh gimme Gimme Okay huh Uh bluff clue Baby
#
#
# Sam Hunt:Take Your Time
# ai hello hi intimidating drunk hell covers conversation lies mine
#
#
# Ed Sheeran:Photograph
# wo sixteen heal jeans photograph soul frozen ourselves alive die
#
#
# Sam Hunt:House Party
# ai homebody soiree babe couch shade furniture roof boom nobody
#
#
# Little Big Town:Girl Crush
# ca whispering perfume lips Yeah sheets crush laugh rush sleep
#
#
# Fall Out Boy:Uma Thurman
# stench eternity Thurman confess lions oh lamb oath tide miracle
#
#
# Wiz Khalifa:See You Again
# gon ooh Damn yeah Ah oh laugh pays friendship crossed
#
#
# Demi Lovato:Cool For The Summer
# n't Shhhh Ooh okay Ha cherry paradise bite scared prize
#
#
# David Guetta:Hey Mama
# dey ai nothin na deuce mama huh Uh coupe uh
#
#
# X Ambassadors:Renegades
# Renegades revelry renegades outlaws mutineers amends underdogs pioneers hey Hey
#
#
# Fetty Wap:Trap Queen
# bando nuttin tho ai 1738 ca talkin nothin Boyz hating
#
#
# Charlie Puth:Marvin Gaye
# babe mercy subtle bone dawn please ourselves yourself song Let
#
#
# Shawn Mendes:Stitches
# ca sow kisses stitches thread begging breathe flame lover knees
#
#
# Thomas Rhett:Crash And Burn
# ca Ai jaded yeah spinning Yeah burn songs baby girl
#
#
# Mark Ronson:Uptown Funk
# gon Livin Bitch Skippy fireman sip masterpieces Pfeiffer hey oh
#
#
# Chris Janson:Buy Me A Boat
# a- redneck Bullets bucket Buffett needle happiness Yeah collar bullets
#
#
# Taylor Swift:Bad Blood
# n't 'em wo Mmm rusted hey ghosts shining Band breathe
#
#
# Jason Derulo:Want To Want Me
# ca Ooh yours yeah cab keys Girl Baby ear smile
#
#
# Eric Church:Like A Wrecking Ball
# wo Sheetrock quaking sink shaking pink falls wall baby Do
#
#
# Keith Urban:John Cougar, John Deere, John 3:16
# Victrola 3:16 swinger levee Cougar Deere whiskey Superman Eden McLean
#
#
# Flo Rida:I Don't Like It, I Love It
# touche ca comin Alright alright Ai condo jackpot ya gotta
#
#
# Pitbull:Fun
# hazy undone disguise shadows shy crazy Oh tonight Let fun
#
#
# DJ Snake & AlunaGeorge:You Know You Like It
# wo ca dreamer follower tails scales insane fool cruel shame
#
#
# Sia:Elastic Heart
# wo blade Yeah dust flags Oh survive apart Let sharp
#
#
# Rich Homie Quan:Flex (Ooh, Ooh, Ooh)
# boppin poppin 'em ai ca ooh toupee Talkin Aye flex
#
#
# Meek Mill:All Eyes On You
# n't gooses bach chinchillas feelin gon ai shit somethin lovin
#
#
# Ed Sheeran:Thinking Out Loud
# ca fades darling cheeks loud mistakes memory hair stars green
#
#
# Blake Shelton:Sangria
# sangria hallway yours shades kiss spinning shoes tonight sun wine
#
#
# Jason Aldean:Tonight Looks Good On You
# Somethin ai blur kiss lips Girl smiling skin baby girl
#
#
# Maroon 5:Sugar
# ai shit ooh alright babe insecure velvet begging oh Sugar
#
#
# Zac Brown Band:Loving You Easy
# candlelight downstairs Easy smile Oh bright touch fast easy list
#
#
# Meghan Trainor:Like I'm Gonna Lose You
# wo moonlight Whoa yeah goodbye regrets Yeah Hey tears disappeared
#
#
# Canaan Smith:Love You Like That
# fishin makin whiskey Baby Mississippi sky ride wine girl picture
#
#
# Tove Lo:Talking Body
# wo lovin Lips fingertips Bodies uh Smoke yeah kiss tears
#
#
# Rihanna:Bitch Better Have My Money
# Shit LeBron playin gon Ballin Bitch doin Moo bitch bluff
#
#
# Elle King:Ex's & Oh's
# wo Whoa getaway hey ghosts Ex seas UK Orleans Oh
#
#
# Brantley Gilbert:One Hell Of An Amen
# waitin Fightin ai ca amen twenty goodbye knees scared Lord
#
#
# Jidenna:Classic Man
# 'em ai OG whoa leprechaun ca dandy pantry don jewel
#
#
# Cam:Burning House
# sleepwalking somehow smoke tight broken wrong gone inside house fire
#
#
# Omi:Cheerleader
# wand cheerleader tempting yeah cheating affection motivation queen selection mention
#
#
# The Weeknd:Earned It
# hey yeah Hey confused tragic magic unexpected rush lies nobody
#
#
# Taylor Swift:Shake It Off
# dancin mmh sayin wo ca hmm Ca nothin ah hey
#
#
# Bea Miller:Fire N Gold
# throttle Eyes madness yeah shine heights cried moon magic bottle
#
#
# George Ezra:Budapest
# Castillo Budapest artifacts piano chest Oh achieved understand words reason
#
#
# Jeremih:Planes
# Ridin feelin rollin gon ai takin shit somethin Lovin babysitting
#
#
# Brett Eldredge:Lose My Mind
# straitjacket fused yeah coaster oh apple planet loose blame brain
#
#
# Taylor Swift:Style
# mmm ca ooh Ca headlights Midnight paradise t oh skirt
#
#
# Meghan Trainor:Dear Future Husband
# lovin alright babe pies kisses Sing hey groceries Buy lonely
#
#
# Jake Owen:Real Life
# livin RC smokes waitress rude oh Coke loud tale anyway
#
#
# Meek Mill:R.I.C.O.
# havin poppin gon Poppin shit ca gettin doin Payback Views
#
#
# Omarion:Post To Be
# gon ai nah Oooh ca groupie groceries freak printer oh
#
#
# Trey Songz:Slow Motion
# wo crib sip darling lips Baby forget motion steady clothes
#
#
# Nicki Minaj:The Night Is Still Young
# gon ai Ayo Ca spaceship bartender Yo okay vodka yeah
#
#
# The Weeknd:Often
# poppin ai somethin smokin Oooh matted nauseous bladder Grain louder
#
#
# Old Dominion:Break Up With Him
# ai ca Naw Okay yeah pretend Girl glove drunk Yeah
#
#
# Echosmith:Bright
# constellation grey Bright aligned bright tonight eyes love face side
#
#
# Rae Sremmurd:This Could Be Us
# actin backseat y'all improvise McGrady wolf dare masters moon bottle
#
#
# Taylor Swift:Blank Space
# n't mmm daydream Screaming thorns breathless Ai jealousy kisses scar
#
#
# Chris Young:I'm Comin' Over
# workin ai runnin Ooooh ca comin goodbye Yeah girl closer
#
#
# T-Wayne:Nasty Freestyle
# ai shit wo playa homeboys Myer Lil alligators machete feeder
#
#
# Florida Georgia Line:Anything Goes
# sippin sayin Gettin ai boombox comin rockin 4x4 Smokin nothin
#
#
# Michael Ray:Kiss You In The Morning
# moonlight glowing outlaw oh butterfly faded hide crazy lights drink
#
#
# Ellie Goulding:Love Me Like You Do
# ca paradise lo Yeah cure satellites touch dark pain pace
#
#
# Future:Fuck Up Some Commas
# goonies shorty gon shit commas ca thou fifty Hendrix racks
#
#
# Adam Lambert:Ghost Town
# vampires disaffected saints disconnected rust satire Tonight gates flames Said
#
#
# Zedd:Beautiful Now
# wo fireflies staring collided breathing clouds crown forever sky tonight
#
#
# Vance Joy:Riptide
# oooh riptide ca unstuck wanna magician gotta oh cowboy gonna
#
#
# Eminem:Kings Never Die
# n't 'em ai shit wo hallucinogens comin quitter Renegade pout
#
#
# Sage The Gemini:Good Thing
# n't gon ai shit ca na Damn Uh damn yeah
#
#
# Tori Kelly:Should've Been Us
# ca yea ooh ya yours yeah pretend oh amazing crazy
#
#
# Fall Out Boy:Centuries
# ca amnesia blossom hey fingerprints bloom Hey shadow dreams centuries
#
#
# Eminem:Phenomenal
# cypher placemat waitin salivation Unstoppable feelin 'em tryin makin gon
#
#
# Maroon 5:This Summer's Gonna Hurt Like A Motherfucker
# Whoo ca bandage eats oh fool diamonds fancy nasty beach
#
#
# Dustin Lynch:Hell Of A Night
# Flyin blowin runnin livin floorboard Oooh crook careless beams yeah
#
#
# Flo Rida:G.D.F.R.
# Bronchitis entendre cobra Midas rover Katrina chicks rackets limousines cough
#
#
# Twenty One Pilots:Tear In My Heart
# carver okay armor oh farther cement soul smile alive sit
#
#
# Pia Mia:Do It Again
# ai lovin ca Pia Lover Bye handler boo exaggeration ya
#
#
# Fetty Wap:My Way
# ai morn shit wo seventeen ca Bitch baddest hoes bitch
